# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

file_path = '/Users/roczhang/Library/CloudStorage/OneDrive-个人/data/demo/data1.csv'
data = pd.read_csv(file_path)
rec = data['Rec'].tolist()
F1 = data['F1'].tolist()
G = data['G'].tolist()
Mcc = data['Mcc'].tolist()

# %%
data
# Out:
#        methods    Acc    Pre    Rec     F1      G    Mcc
# 0         KFCM  81.25  97.30  64.29  77.42  79.46  66.44
# 1       D-KFCM  86.61  91.84  80.36  85.71  86.38  73.79
# 2           RU  76.78  94.12  57.14  71.11  74.23  58.26
# 3     NearMiss  75.89  83.72  64.29  72.73  75.00  53.24
# 4           RO  70.54  89.66  46.43  61.18  66.29  46.88
# 5        SMOTE  67.86  88.46  41.07  56.10  62.35  42.30
# 6  Border-line  72.32  90.32  50.00  64.37  68.79  49.89
# 7       ADASYN  67.86  88.46  41.07  56.10  62.35  42.30
# 8    SMOTE-ENN  69.64  89.29  44.64  59.52  65.00  45.36
# 9  SMOTE-Tomek  67.86  88.46  41.07  56.10  62.35  42.30

# %%
# t = ['KFCM', 'D-KFCM', 'RU', 'NearMiss', 'RO', 'SMOTE', 'Border-line', 'ADASYN', 'SMOTE-ENN', 'SMOTE-Tomek']
t = ['KFCM', 'D-KFCM', 'RU', 'NearMiss', 'RO', 'SMOTE', 'BS', 'ADASYN', 'SE', 'ST']

fig = plt.figure(figsize=(7, 5))
plt.plot(t, rec, 'go--', label='Recall')
plt.plot(t, F1, 'bv-', label='F1')
plt.plot(t, G, 'c^-.', label='G-mean')
plt.plot(t, Mcc, 'r>:', label='MCC')

# plt.set_ylim(20, 100)
# ax.set_xticklabels(t, rotation=75)
# fig.tight_layout()
plt.legend(loc='lower left')
plt.show()

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

dt = 0.01
t = np.arange(0, 30, dt)
nse1 = np.random.randn(len(t))                 # white noise 1
nse2 = np.random.randn(len(t))                 # white noise 2

# Two signals with a coherent part at 10Hz and a random part
s1 = np.sin(2 * np.pi * 10 * t) + nse1
s2 = np.sin(2 * np.pi * 10 * t) + nse2

fig, axs = plt.subplots(2, 1)
axs[0].plot(t, s1, t, s2)
axs[0].set_xlim(0, 2)
axs[0].set_xlabel('time')
axs[0].set_ylabel('s1 and s2')
axs[0].grid(True)

cxy, f = axs[1].cohere(s1, s2, 256, 1. / dt)
axs[1].set_ylabel('coherence')

fig.tight_layout()
plt.show()

# %%
s1
# Out:
# array([ 1.04930431,  1.45388443,  1.50219112, ..., -1.98986183,
#        -1.51153048, -1.5387947 ])

# %%
file_path = '/Users/roczhang/Library/CloudStorage/OneDrive-个人/data/demo/data2.csv'
data = pd.read_csv(file_path)
rec = data['Rec'].tolist()
F1 = data['F1'].tolist()
G = data['G'].tolist()
Mcc = data['Mcc'].tolist()

# t = ['KFCM', 'D-KFCM', 'RU', 'NearMiss', 'RO', 'SMOTE', 'Border-line', 'ADASYN', 'SMOTE-ENN', 'SMOTE-Tomek']
t = ['KFCM', 'D-KFCM', 'RU', 'NearMiss', 'RO', 'SMOTE', 'BS', 'ADASYN', 'SE', 'ST']

fig = plt.figure(figsize=(7, 5))
plt.plot(t, rec, 'go--', label='Recall')
plt.plot(t, F1, 'bv-', label='F1')
plt.plot(t, G, 'c^-.', label='G-mean')
plt.plot(t, Mcc, 'r>:', label='MCC')

# plt.set_ylim(20, 100)
# ax.set_xticklabels(t, rotation=75)
# fig.tight_layout()
plt.legend(loc='lower left')
plt.show()

# %%
file_path = '/Users/roczhang/Library/CloudStorage/OneDrive-个人/data/demo/data3.csv'
data = pd.read_csv(file_path)
rec = data['Rec'].tolist()
F1 = data['F1'].tolist()
G = data['G'].tolist()
Mcc = data['Mcc'].tolist()

# t = ['KFCM', 'D-KFCM', 'RU', 'NearMiss', 'RO', 'SMOTE', 'Border-line', 'ADASYN', 'SMOTE-ENN', 'SMOTE-Tomek']
t = ['KFCM', 'D-KFCM', 'RU', 'NearMiss', 'RO', 'SMOTE', 'BS', 'ADASYN', 'SE', 'ST']

fig = plt.figure(figsize=(7, 5))
plt.plot(t, rec, 'go--', label='Recall')
plt.plot(t, F1, 'bv-', label='F1')
plt.plot(t, G, 'c^-.', label='G-mean')
plt.plot(t, Mcc, 'r>:', label='MCC')

# plt.set_ylim(20, 100)
# ax.set_xticklabels(t, rotation=75)
# fig.tight_layout()
plt.legend(loc='best')
plt.show()

# %%
file_path = '/Users/roczhang/Library/CloudStorage/OneDrive-个人/data/demo/data4.csv'
data = pd.read_csv(file_path)
rec = data['Rec'].tolist()
F1 = data['F1'].tolist()
G = data['G'].tolist()
Mcc = data['Mcc'].tolist()

# t = ['KFCM', 'D-KFCM', 'RU', 'NearMiss', 'RO', 'SMOTE', 'Border-line', 'ADASYN', 'SMOTE-ENN', 'SMOTE-Tomek']
t = ['KFCM', 'D-KFCM', 'RU', 'NearMiss', 'RO', 'SMOTE', 'BS', 'ADASYN', 'SE', 'ST']

fig = plt.figure(figsize=(7, 5))
plt.plot(t, rec, 'go--', label='Recall')
plt.plot(t, F1, 'bv-', label='F1')
plt.plot(t, G, 'c^-.', label='G-mean')
plt.plot(t, Mcc, 'r>:', label='MCC')

# plt.set_ylim(20, 100)
# ax.set_xticklabels(t, rotation=75)
# fig.tight_layout()
plt.legend(loc='best')
plt.show()
